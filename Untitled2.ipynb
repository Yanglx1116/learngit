# %% [markdown]
# shell echo命令

# %% [markdown]
# ![bfa7ea80fea430d9de327cfa46a472c.png](attachment:835a1b1e-7541-46c8-90bd-4051f5d9044f.png)

# %% [markdown]
# ![5d40bb5f63b7c871ada913e1edfedae.png](attachment:8d5045f3-054a-4c28-ac27-b2e008ad65e4.png)

# %% [markdown]
# shell print命令

# %% [markdown]
# ![6b6c84b2d3c5aa012a2bc8c8517034c.png](attachment:a4983f9b-c16b-4789-8c28-3c40bb492139.png)

# %% [markdown]
# ![8ee2c33eacd829f816e227d0870e3ba.png](attachment:0c2005a0-0cd0-474b-9bda-2dc0c8f74c99.png)
