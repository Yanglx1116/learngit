# %% [markdown]
# shell函数

# %% [markdown]
# ![cc3cb7f0d866342c9741d861baf4b49.png](attachment:827ab217-385d-44d8-a212-c229c6348c43.png)

# %% [markdown]
# ![e61220cfb410460a4983955928c1c66.png](attachment:b1960c82-d2a7-4e06-81db-ef5ac5d88534.png)

# %% [markdown]
# ![f2c2d239c81be004f013a71c913394b.png](attachment:9e5cc6d7-f83f-4c77-b3c8-59645f6af34c.png)

# %% [markdown]
# shell输入/输出重定向

# %% [markdown]
# ![e6363cadfa72dc785b85540ebce9244.png](attachment:c18ab508-5faa-4f99-9258-0d2fbb4ebcaf.png)

# %% [markdown]
# ![da792ac89418f1d457039dac09f598d.png](attachment:4c2a5d15-3685-4826-8121-f4512a48122d.png)

# %% [markdown]
# shell文件包含

# %% [markdown]
# ![749203e9365604ab8fc81a04aabbbbd.png](attachment:bf5931d7-b7e6-42c9-a43f-93721311ef9e.png)
